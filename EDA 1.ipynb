# %%
#load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the csv file
data=pd.read_csv('Cardiotocographic.csv')

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#to check no.of rows and columns
data.shape
# Out:
# (2126, 14)

# %%
#first 5 rows
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
#last 5 rows
data.tail()
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %% [markdown]
# #1.Data cleaning and preparation

# %%
#finding the missing values
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
#filling the missing values with mean
data["LB"] = data["LB"].fillna(data["LB"].mean())
data["AC"] = data["AC"].fillna(data["AC"].mean())
data["DS"] = data["DS"].fillna(data["DS"].mean())
data["DP"] = data["DP"].fillna(data["DP"].mean())
data["MLTV"] = data["MLTV"].fillna(data["MLTV"].mean())
data["Width"] = data["Width"].fillna(data["Width"].mean())
data["Tendency"] = data["Tendency"].fillna(data["Tendency"].mean())
data["NSP"] = data["NSP"].fillna(data["NSP"].mean())

# %%
data.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
#to display the datatype
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2126 non-null   float64
#  1   AC        2126 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2126 non-null   float64
#  6   DP        2126 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2126 non-null   float64
#  11  Width     2126 non-null   float64
#  12  Tendency  2126 non-null   float64
#  13  NSP       2126 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
#check the duplicates
data.duplicated().sum()
# Out:
# np.int64(2)

# %%
#removing the duplicate data
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#check any inconsistent datatypes occur
data.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
#detect and treat outliers
data.boxplot()
plt.title('Box Plot of Numerical Variables')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2124 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2124 non-null   float64
#  1   AC        2124 non-null   float64
#  2   FM        2124 non-null   float64
#  3   UC        2124 non-null   float64
#  4   DL        2124 non-null   float64
#  5   DS        2124 non-null   float64
#  6   DP        2124 non-null   float64
#  7   ASTV      2124 non-null   float64
#  8   MSTV      2124 non-null   float64
#  9   ALTV      2124 non-null   float64
#  10  MLTV      2124 non-null   float64
#  11  Width     2124 non-null   float64
#  12  Tendency  2124 non-null   float64
#  13  NSP       2124 non-null   float64
# dtypes: float64(14)
# memory usage: 248.9 KB

# %% [markdown]
# #detecting and treating outliers

# %%
def treat_outliers_iqr(data, columns):
    for col in columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
    return data

# %%
#treating outliers
columns_to_treat = ['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width','Tendency','NSP']
data_cleaned = treat_outliers_iqr(data, columns_to_treat)

# %%
#shape of cleaned dataframe
print(data_cleaned.shape)
# Out:
# (911, 14)

# %%
data_cleaned  #the cleaned dataset
# Out:
#          LB        AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# 1     132.0  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 2     133.0  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 58    148.0  0.000000  0.000000  0.005181  0.000000  0.0  0.0  41.0   0.8
# 59    144.0  0.008143  0.000000  0.006595  0.000000  0.0  0.0  33.0   1.1
# 61    146.0  0.004580 -0.001776  0.004580  0.000000  0.0  0.0  39.0   0.8
# ...     ...       ...       ...       ...       ...  ...  ...   ...   ...
# 2117  140.0  0.000000  0.000000  0.007812  0.000000  0.0  0.0  79.0   0.3
# 2118  140.0  0.000000  0.000000  0.006470  0.000898  0.0  0.0  79.0   0.5
# 2119  140.0  0.000000  0.000000  0.006764  0.001127  0.0  0.0  79.0   0.6
# 2120  140.0  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0   0.7
# 2125  142.0  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency  NSP
# ...

# %% [markdown]
# #statistical summary

# %%
summary = pd.DataFrame({
    "mean": data_cleaned.mean(),
    "median": data_cleaned.median(),
    "std": data_cleaned.std(),
    "IQR": data_cleaned.quantile(0.75) - data_cleaned.quantile(0.25)})

# %%
summary
# Out:
#                 mean      median        std        IQR
# LB        132.238779  133.000000   9.414025  14.000000
# AC          0.003880    0.003014   0.003720   0.006520
# FM          0.000597    0.000000   0.001320   0.000296
# UC          0.004894    0.004985   0.002684   0.003736
# DL          0.001534    0.000000   0.002273   0.002761
# DS          0.000000    0.000000   0.000000   0.000000
# DP          0.000000    0.000000   0.000000   0.000000
# ASTV       42.972924   42.000000  15.131325  27.000000
# MSTV        1.219414    1.200000   0.502265   0.700000
# ALTV        4.622635    0.000000   8.733828   5.129702
# MLTV        8.428988    8.200000   4.371035   5.500000
# Width      65.678534   59.000000  31.473860  52.000000
# Tendency    0.349104    0.000000   0.584673   1.000000
# NSP         1.000000    1.000000   0.000000   0.000000

# %% [markdown]
# #Data Visualization

# %% [markdown]
# ##histogram

# %%
data_cleaned.hist(figsize=(16, 12), bins=30)
plt.suptitle("Histograms of Numerical Variables")
plt.show()

# %% [markdown]
# ##box plot

# %%
data_cleaned.plot(kind='box', figsize=(12, 6))
plt.title("Box Plot of All Numerical Columns")
plt.show()

# %% [markdown]
# ##bar chart
# here categorical column is NSP

# %%
data_cleaned['NSP'].value_counts().plot(kind='bar', color='skyblue')
plt.title("Distribution of NSP Classes")
plt.xlabel("NSP Class")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##scatter plot

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='ASTV', y='ALTV', data=data_cleaned,hue='NSP')
plt.title('Scatter Plot: ASTV vs ALTV by NSP')
plt.xlabel('ASTV')
plt.ylabel('ALTV')
plt.show()

# %% [markdown]
# ##heat map

# %%
#Calculate correlation matrix
corr = data_cleaned.corr()

# Correlation Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ##pair plot

# %%
# Pair plot (selected features)
selected_cols = ['ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width', 'NSP']
sns.pairplot(data_cleaned[selected_cols], hue='NSP')
plt.suptitle("Pair Plot of Selected Features", y=1.0)
plt.show()

# %% [markdown]
# #Pattern Recognition and Insights

# %%
#ASTV, ALTV and MLTV can be important predictors for fetal health classification (NSP).
#Features like DL, DS, DP, and FM often have very low values (mostly 0), resulting in near-zero correlations with other variables.

# %% [markdown]
# ##key insights and findings

# %%
#Higher ASTV and ALTV values are generally associated with normal fetal states (NSP = 1).

#Lower variability (MLTV, MSTV) appears more frequently in pathological cases (NSP = 3)

#DS and DP are constant across all rows and have no impact on analysis—these should be removed from modeling steps.

#NSP is correlated with ASTV and MLTV, making them valuable for classification tasks.
